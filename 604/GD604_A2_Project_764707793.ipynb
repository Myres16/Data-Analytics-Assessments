# %%
import pandas as pd
import numpy as np
# Out:
# C:\Users\torri\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
# Task A
# a.
sales_df=pd.read_csv('Sales_Sample_Public_Dataset.csv')
sales_df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0      2/24/2003 0:00   Shipped       1         2     2003  ...
# 1      5/07/2003 0:00   Shipped       2         5     2003  ...
# 2      7/01/2003 0:00   Shipped       3         7     2003  ...
# 3      8/25/2003 0:00   Shipped       3         8     2003  ...
# 4     10/10/2003 0:00   Shipped       4        10     2003  ...
# ...               ...       ...     ...       ...      ...  ...
# 2818  12/02/2004 0:00   Shipped       4        12     2004  ...
# 2819   1/31/2005 0:00   Shipped       1         1     2005  ...
# 2820   3/01/2005 0:00  Resolved       1         3     2005  ...
# 2821   3/28/2005 0:00   Shipped       1         3     2005  ...
# 2822   5/06/2005 0:00   On Hold       2         5     2005  ...
#
#                        ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0           897 Long Airport Avenue           NaN            NYC    NY
# 1                59 rue de l'Abbaye           NaN          Reims   NaN
# 2     27 rue du Colonel Pierre Avia           NaN          Paris   NaN
# 3                78934 Hillside Dr.           NaN       Pasadena    CA
# 4                   7734 Strong St.           NaN  San Francisco    CA
# ...                             ...           ...            ...   ...
# 2818             C/ Moralzarzal, 86           NaN         Madrid   NaN
# 2819                    Torikatu 38           NaN           Oulu   NaN
# 2820             C/ Moralzarzal, 86           NaN         Madrid   NaN
# 2821          1 rue Alsace-Lorraine           NaN       Toulouse   NaN
# 2822             8616 Spinnaker Dr.           NaN         Boston    MA
#
#      POSTALCODE  COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 0         10022      USA       NaN              Yu             Kwai    Small
# 1         51100   France      EMEA         Henriot             Paul    Small
# 2         75508   France      EMEA        Da Cunha           Daniel   Medium
# 3         90003      USA       NaN           Young            Julie   Medium
# 4           NaN      USA       NaN           Brown            Julie   Medium
# ...         ...      ...       ...             ...              ...      ...
# 2818      28034    Spain      EMEA          Freyre            Diego    Small
# 2819      90110  Finland      EMEA       Koskitalo           Pirkko   Medium
# 2820      28034    Spain      EMEA          Freyre            Diego   Medium
# 2821      31000   France      EMEA          Roulet          Annette    Small
# 2822      51003      USA       NaN         Yoshido             Juri   Medium
#
# [2823 rows x 25 columns]

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
#  16  ADDRESSLINE2      302 non-null    object
#  17  CITY              2823 non-null   object
#  18  STATE             1337 non-null   object
#  19  POSTALCODE        2747 non-null   object
#  20  COUNTRY           2823 non-null   object
#  21  TERRITORY         1749 non-null   object
#  22  CONTACTLASTNAME   2823 non-null   object
#  23  CONTACTFIRSTNAME  2823 non-null   object
#  24  DEALSIZE          2823 non-null   object
# dtypes: float64(2), int64(7), object(16)
# memory usage: 551.5+ KB

# %%
sales_df.describe
# Out:
# <bound method NDFrame.describe of       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0      2/24/2003 0:00   Shipped       1         2     2003  ...
# 1      5/07/2003 0:00   Shipped       2         5     2003  ...
# 2      7/01/2003 0:00   Shipped       3         7     2003  ...
# 3      8/25/2003 0:00   Shipped       3         8     2003  ...
# 4     10/10/2003 0:00   Shipped       4        10     2003  ...
# ...               ...       ...     ...       ...      ...  ...
# 2818  12/02/2004 0:00   Shipped       4        12     2004  ...
# 2819   1/31/2005 0:00   Shipped       1         1     2005  ...
# 2820   3/01/2005 0:00  Resolved       1         3     2005  ...
# 2821   3/28/2005 0:00   Shipped       1         3     2005  ...
# 2822   5/06/2005 0:00   On Hold       2         5     2005  ...
#
#                        ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0           897 Long Airport Avenue           NaN            NYC    NY
# 1                59 rue de l'Abbaye           NaN          Reims   NaN
# 2     27 rue du Colonel Pierre Avia           NaN          Paris   NaN
# 3                78934 Hillside Dr.           NaN       Pasadena    CA
# 4                   7734 Strong St.           NaN  San Francisco    CA
# ...                             ...           ...            ...   ...
# 2818             C/ Moralzarzal, 86           NaN         Madrid   NaN
# 2819                    Torikatu 38           NaN           Oulu   NaN
# 2820             C/ Moralzarzal, 86           NaN         Madrid   NaN
# 2821          1 rue Alsace-Lorraine           NaN       Toulouse   NaN
# 2822             8616 Spinnaker Dr.           NaN         Boston    MA
#
#      POSTALCODE  COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 0         10022      USA       NaN              Yu             Kwai    Small
# 1         51100   France      EMEA         Henriot             Paul    Small
# 2         75508   France      EMEA        Da Cunha           Daniel   Medium
# 3         90003      USA       NaN           Young            Julie   Medium
# 4           NaN      USA       NaN           Brown            Julie   Medium
# ...         ...      ...       ...             ...              ...      ...
# 2818      28034    Spain      EMEA          Freyre            Diego    Small
# 2819      90110  Finland      EMEA       Koskitalo           Pirkko   Medium
# 2820      28034    Spain      EMEA          Freyre            Diego   Medium
# 2821      31000   France      EMEA          Roulet          Annette    Small
# 2822      51003      USA       NaN         Yoshido             Juri   Medium
#
# [2823 rows x 25 columns]>

# %%
# b. 
sales_df.head(10)
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
# 5        10168               36      96.66                1  3479.76
# 6        10180               29      86.13                9  2497.77
# 7        10188               48     100.00                1  5512.32
# 8        10201               22      98.57                2  2168.54
# 9        10211               41     100.00               14  4708.44
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1   5/07/2003 0:00  Shipped       2         5     2003  ...
# 2   7/01/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
# 5  10/28/2003 0:00  Shipped       4        10     2003  ...
# 6  11/11/2003 0:00  Shipped       4        11     2003  ...
# 7  11/18/2003 0:00  Shipped       4        11     2003  ...
# 8  12/01/2003 0:00  Shipped       4        12     2003  ...
# 9   1/15/2004 0:00  Shipped       1         1     2004  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# 1             59 rue de l'Abbaye           NaN          Reims   NaN
# 2  27 rue du Colonel Pierre Avia           NaN          Paris   NaN
# 3             78934 Hillside Dr.           NaN       Pasadena    CA
# 4                7734 Strong St.           NaN  San Francisco    CA
# 5              9408 Furth Circle           NaN     Burlingame    CA
# 6        184, chausse de Tournai           NaN          Lille   NaN
# 7    Drammen 121, PR 744 Sentrum           NaN         Bergen   NaN
# 8      5557 North Pendale Street           NaN  San Francisco    CA
# 9              25, rue Lauriston           NaN          Paris   NaN
#
#   POSTALCODE COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 0      10022     USA       NaN              Yu             Kwai    Small
# 1      51100  France      EMEA         Henriot             Paul    Small
# 2      75508  France      EMEA        Da Cunha           Daniel   Medium
# 3      90003     USA       NaN           Young            Julie   Medium
# 4        NaN     USA       NaN           Brown            Julie   Medium
# 5      94217     USA       NaN          Hirano             Juri   Medium
# 6      59000  France      EMEA           Rance          Martine    Small
# 7     N 5804  Norway      EMEA          Oeztan           Veysel   Medium
# 8        NaN     USA       NaN          Murphy            Julie    Small
# 9      75016  France      EMEA         Perrier        Dominique   Medium
#
# [10 rows x 25 columns]

# %%
#c.1 Identifying the null values
sales_df.isnull().sum()
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# ADDRESSLINE2        2521
# CITY                   0
# STATE               1486
# POSTALCODE            76
# COUNTRY                0
# TERRITORY           1074
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %%
# c.2 : Replacing TERRITORY null values by empty value
sales_df['TERRITORY']=sales_df['TERRITORY'].fillna('')
sales_df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0      2/24/2003 0:00   Shipped       1         2     2003  ...
# 1      5/07/2003 0:00   Shipped       2         5     2003  ...
# 2      7/01/2003 0:00   Shipped       3         7     2003  ...
# 3      8/25/2003 0:00   Shipped       3         8     2003  ...
# 4     10/10/2003 0:00   Shipped       4        10     2003  ...
# ...               ...       ...     ...       ...      ...  ...
# 2818  12/02/2004 0:00   Shipped       4        12     2004  ...
# 2819   1/31/2005 0:00   Shipped       1         1     2005  ...
# 2820   3/01/2005 0:00  Resolved       1         3     2005  ...
# 2821   3/28/2005 0:00   Shipped       1         3     2005  ...
# 2822   5/06/2005 0:00   On Hold       2         5     2005  ...
#
#                        ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0           897 Long Airport Avenue           NaN            NYC    NY
# 1                59 rue de l'Abbaye           NaN          Reims   NaN
# 2     27 rue du Colonel Pierre Avia           NaN          Paris   NaN
# 3                78934 Hillside Dr.           NaN       Pasadena    CA
# 4                   7734 Strong St.           NaN  San Francisco    CA
# ...                             ...           ...            ...   ...
# 2818             C/ Moralzarzal, 86           NaN         Madrid   NaN
# 2819                    Torikatu 38           NaN           Oulu   NaN
# 2820             C/ Moralzarzal, 86           NaN         Madrid   NaN
# 2821          1 rue Alsace-Lorraine           NaN       Toulouse   NaN
# 2822             8616 Spinnaker Dr.           NaN         Boston    MA
#
#      POSTALCODE  COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 0         10022      USA                        Yu             Kwai    Small
# 1         51100   France      EMEA         Henriot             Paul    Small
# 2         75508   France      EMEA        Da Cunha           Daniel   Medium
# 3         90003      USA                     Young            Julie   Medium
# 4           NaN      USA                     Brown            Julie   Medium
# ...         ...      ...       ...             ...              ...      ...
# 2818      28034    Spain      EMEA          Freyre            Diego    Small
# 2819      90110  Finland      EMEA       Koskitalo           Pirkko   Medium
# 2820      28034    Spain      EMEA          Freyre            Diego   Medium
# 2821      31000   France      EMEA          Roulet          Annette    Small
# 2822      51003      USA                   Yoshido             Juri   Medium
#
# [2823 rows x 25 columns]

# %%
#c.2
sales_df['STATE']=sales_df['STATE'].fillna('NA')
sales_df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0      2/24/2003 0:00   Shipped       1         2     2003  ...
# 1      5/07/2003 0:00   Shipped       2         5     2003  ...
# 2      7/01/2003 0:00   Shipped       3         7     2003  ...
# 3      8/25/2003 0:00   Shipped       3         8     2003  ...
# 4     10/10/2003 0:00   Shipped       4        10     2003  ...
# ...               ...       ...     ...       ...      ...  ...
# 2818  12/02/2004 0:00   Shipped       4        12     2004  ...
# 2819   1/31/2005 0:00   Shipped       1         1     2005  ...
# 2820   3/01/2005 0:00  Resolved       1         3     2005  ...
# 2821   3/28/2005 0:00   Shipped       1         3     2005  ...
# 2822   5/06/2005 0:00   On Hold       2         5     2005  ...
#
#                        ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0           897 Long Airport Avenue           NaN            NYC    NY
# 1                59 rue de l'Abbaye           NaN          Reims    NA
# 2     27 rue du Colonel Pierre Avia           NaN          Paris    NA
# 3                78934 Hillside Dr.           NaN       Pasadena    CA
# 4                   7734 Strong St.           NaN  San Francisco    CA
# ...                             ...           ...            ...   ...
# 2818             C/ Moralzarzal, 86           NaN         Madrid    NA
# 2819                    Torikatu 38           NaN           Oulu    NA
# 2820             C/ Moralzarzal, 86           NaN         Madrid    NA
# 2821          1 rue Alsace-Lorraine           NaN       Toulouse    NA
# 2822             8616 Spinnaker Dr.           NaN         Boston    MA
#
#      POSTALCODE  COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 0         10022      USA                        Yu             Kwai    Small
# 1         51100   France      EMEA         Henriot             Paul    Small
# 2         75508   France      EMEA        Da Cunha           Daniel   Medium
# 3         90003      USA                     Young            Julie   Medium
# 4           NaN      USA                     Brown            Julie   Medium
# ...         ...      ...       ...             ...              ...      ...
# 2818      28034    Spain      EMEA          Freyre            Diego    Small
# 2819      90110  Finland      EMEA       Koskitalo           Pirkko   Medium
# 2820      28034    Spain      EMEA          Freyre            Diego   Medium
# 2821      31000   France      EMEA          Roulet          Annette    Small
# 2822      51003      USA                   Yoshido             Juri   Medium
#
# [2823 rows x 25 columns]

# %%
# c.3 : Dropping ADDRESSLINE2 as it is not needed in the analysis
sales_df=sales_df.drop(columns=['ADDRESSLINE2'])
sales_df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0      2/24/2003 0:00   Shipped       1         2     2003  ...
# 1      5/07/2003 0:00   Shipped       2         5     2003  ...
# 2      7/01/2003 0:00   Shipped       3         7     2003  ...
# 3      8/25/2003 0:00   Shipped       3         8     2003  ...
# 4     10/10/2003 0:00   Shipped       4        10     2003  ...
# ...               ...       ...     ...       ...      ...  ...
# 2818  12/02/2004 0:00   Shipped       4        12     2004  ...
# 2819   1/31/2005 0:00   Shipped       1         1     2005  ...
# 2820   3/01/2005 0:00  Resolved       1         3     2005  ...
# 2821   3/28/2005 0:00   Shipped       1         3     2005  ...
# 2822   5/06/2005 0:00   On Hold       2         5     2005  ...
#
#                  PHONE                   ADDRESSLINE1           CITY STATE  \
# 0           2125557818        897 Long Airport Avenue            NYC    NY
# 1           26.47.1555             59 rue de l'Abbaye          Reims    NA
# 2     +33 1 46 62 7555  27 rue du Colonel Pierre Avia          Paris    NA
# 3           6265557265             78934 Hillside Dr.       Pasadena    CA
# 4           6505551386                7734 Strong St.  San Francisco    CA
# ...                ...                            ...            ...   ...
# 2818    (91) 555 94 44             C/ Moralzarzal, 86         Madrid    NA
# 2819        981-443655                    Torikatu 38           Oulu    NA
# 2820    (91) 555 94 44             C/ Moralzarzal, 86         Madrid    NA
# 2821        61.77.6555          1 rue Alsace-Lorraine       Toulouse    NA
# 2822        6175559555             8616 Spinnaker Dr.         Boston    MA
#
#      POSTALCODE  COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 0         10022      USA                        Yu             Kwai    Small
# 1         51100   France      EMEA         Henriot             Paul    Small
# 2         75508   France      EMEA        Da Cunha           Daniel   Medium
# 3         90003      USA                     Young            Julie   Medium
# 4           NaN      USA                     Brown            Julie   Medium
# ...         ...      ...       ...             ...              ...      ...
# 2818      28034    Spain      EMEA          Freyre            Diego    Small
# 2819      90110  Finland      EMEA       Koskitalo           Pirkko   Medium
# 2820      28034    Spain      EMEA          Freyre            Diego   Medium
# 2821      31000   France      EMEA          Roulet          Annette    Small
# 2822      51003      USA                   Yoshido             Juri   Medium
#
# [2823 rows x 24 columns]

# %%
#c.2
sales_df['POSTALCODE']=sales_df['POSTALCODE'].fillna('None')
sales_df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0      2/24/2003 0:00   Shipped       1         2     2003  ...
# 1      5/07/2003 0:00   Shipped       2         5     2003  ...
# 2      7/01/2003 0:00   Shipped       3         7     2003  ...
# 3      8/25/2003 0:00   Shipped       3         8     2003  ...
# 4     10/10/2003 0:00   Shipped       4        10     2003  ...
# ...               ...       ...     ...       ...      ...  ...
# 2818  12/02/2004 0:00   Shipped       4        12     2004  ...
# 2819   1/31/2005 0:00   Shipped       1         1     2005  ...
# 2820   3/01/2005 0:00  Resolved       1         3     2005  ...
# 2821   3/28/2005 0:00   Shipped       1         3     2005  ...
# 2822   5/06/2005 0:00   On Hold       2         5     2005  ...
#
#                  PHONE                   ADDRESSLINE1           CITY STATE  \
# 0           2125557818        897 Long Airport Avenue            NYC    NY
# 1           26.47.1555             59 rue de l'Abbaye          Reims    NA
# 2     +33 1 46 62 7555  27 rue du Colonel Pierre Avia          Paris    NA
# 3           6265557265             78934 Hillside Dr.       Pasadena    CA
# 4           6505551386                7734 Strong St.  San Francisco    CA
# ...                ...                            ...            ...   ...
# 2818    (91) 555 94 44             C/ Moralzarzal, 86         Madrid    NA
# 2819        981-443655                    Torikatu 38           Oulu    NA
# 2820    (91) 555 94 44             C/ Moralzarzal, 86         Madrid    NA
# 2821        61.77.6555          1 rue Alsace-Lorraine       Toulouse    NA
# 2822        6175559555             8616 Spinnaker Dr.         Boston    MA
#
#      POSTALCODE  COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 0         10022      USA                        Yu             Kwai    Small
# 1         51100   France      EMEA         Henriot             Paul    Small
# 2         75508   France      EMEA        Da Cunha           Daniel   Medium
# 3         90003      USA                     Young            Julie   Medium
# 4          None      USA                     Brown            Julie   Medium
# ...         ...      ...       ...             ...              ...      ...
# 2818      28034    Spain      EMEA          Freyre            Diego    Small
# 2819      90110  Finland      EMEA       Koskitalo           Pirkko   Medium
# 2820      28034    Spain      EMEA          Freyre            Diego   Medium
# 2821      31000   France      EMEA          Roulet          Annette    Small
# 2822      51003      USA                   Yoshido             Juri   Medium
#
# [2823 rows x 24 columns]

# %%
sales_df.isnull().sum()
# Out:
# ORDERNUMBER         0
# QUANTITYORDERED     0
# PRICEEACH           0
# ORDERLINENUMBER     0
# SALES               0
# ORDERDATE           0
# STATUS              0
# QTR_ID              0
# MONTH_ID            0
# YEAR_ID             0
# PRODUCTLINE         0
# MSRP                0
# PRODUCTCODE         0
# CUSTOMERNAME        0
# PHONE               0
# ADDRESSLINE1        0
# CITY                0
# STATE               0
# POSTALCODE          0
# COUNTRY             0
# TERRITORY           0
# CONTACTLASTNAME     0
# CONTACTFIRSTNAME    0
# DEALSIZE            0
# dtype: int64

# %%
# Checking for duplicates
duplicated_rows = sales_df[sales_df.duplicated()]
duplicated_rows
# Out:
# Empty DataFrame
# Columns: [ORDERNUMBER, QUANTITYORDERED, PRICEEACH, ORDERLINENUMBER, SALES, ORDERDATE, STATUS, QTR_ID, MONTH_ID, YEAR_ID, PRODUCTLINE, MSRP, PRODUCTCODE, CUSTOMERNAME, PHONE, ADDRESSLINE1, CITY, STATE, POSTALCODE, COUNTRY, TERRITORY, CONTACTLASTNAME, CONTACTFIRSTNAME, DEALSIZE]
# Index: []
#
# [0 rows x 24 columns]

# %%
# formatting the PHONE number

sales_df['PHONE'] = sales_df['PHONE'].str.replace(r'\D', '', regex=True)
sales_df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...        PHONE  \
# 0      2/24/2003 0:00   Shipped       1         2     2003  ...   2125557818
# 1      5/07/2003 0:00   Shipped       2         5     2003  ...     26471555
# 2      7/01/2003 0:00   Shipped       3         7     2003  ...  33146627555
# 3      8/25/2003 0:00   Shipped       3         8     2003  ...   6265557265
# 4     10/10/2003 0:00   Shipped       4        10     2003  ...   6505551386
# ...               ...       ...     ...       ...      ...  ...          ...
# 2818  12/02/2004 0:00   Shipped       4        12     2004  ...    915559444
# 2819   1/31/2005 0:00   Shipped       1         1     2005  ...    981443655
# 2820   3/01/2005 0:00  Resolved       1         3     2005  ...    915559444
# 2821   3/28/2005 0:00   Shipped       1         3     2005  ...     61776555
# 2822   5/06/2005 0:00   On Hold       2         5     2005  ...   6175559555
#
#                        ADDRESSLINE1           CITY STATE POSTALCODE  COUNTRY  \
# 0           897 Long Airport Avenue            NYC    NY      10022      USA
# 1                59 rue de l'Abbaye          Reims    NA      51100   France
# 2     27 rue du Colonel Pierre Avia          Paris    NA      75508   France
# 3                78934 Hillside Dr.       Pasadena    CA      90003      USA
# 4                   7734 Strong St.  San Francisco    CA       None      USA
# ...                             ...            ...   ...        ...      ...
# 2818             C/ Moralzarzal, 86         Madrid    NA      28034    Spain
# 2819                    Torikatu 38           Oulu    NA      90110  Finland
# 2820             C/ Moralzarzal, 86         Madrid    NA      28034    Spain
# 2821          1 rue Alsace-Lorraine       Toulouse    NA      31000   France
# 2822             8616 Spinnaker Dr.         Boston    MA      51003      USA
#
#      TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 0                           Yu             Kwai    Small
# 1         EMEA         Henriot             Paul    Small
# 2         EMEA        Da Cunha           Daniel   Medium
# 3                        Young            Julie   Medium
# 4                        Brown            Julie   Medium
# ...        ...             ...              ...      ...
# 2818      EMEA          Freyre            Diego    Small
# 2819      EMEA       Koskitalo           Pirkko   Medium
# 2820      EMEA          Freyre            Diego   Medium
# 2821      EMEA          Roulet          Annette    Small
# 2822                   Yoshido             Juri   Medium
#
# [2823 rows x 24 columns]

# %%
#removing the date stamp

sales_df['ORDERDATE'] = pd.to_datetime(sales_df['ORDERDATE'], format='%m/%d/%Y %H:%M')
sales_df['ORDERDATE'] = sales_df['ORDERDATE'].dt.strftime('%m/%d/%Y')
sales_df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#        ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...        PHONE  \
# 0     02/24/2003   Shipped       1         2     2003  ...   2125557818
# 1     05/07/2003   Shipped       2         5     2003  ...     26471555
# 2     07/01/2003   Shipped       3         7     2003  ...  33146627555
# 3     08/25/2003   Shipped       3         8     2003  ...   6265557265
# 4     10/10/2003   Shipped       4        10     2003  ...   6505551386
# ...          ...       ...     ...       ...      ...  ...          ...
# 2818  12/02/2004   Shipped       4        12     2004  ...    915559444
# 2819  01/31/2005   Shipped       1         1     2005  ...    981443655
# 2820  03/01/2005  Resolved       1         3     2005  ...    915559444
# 2821  03/28/2005   Shipped       1         3     2005  ...     61776555
# 2822  05/06/2005   On Hold       2         5     2005  ...   6175559555
#
#                        ADDRESSLINE1           CITY STATE POSTALCODE  COUNTRY  \
# 0           897 Long Airport Avenue            NYC    NY      10022      USA
# 1                59 rue de l'Abbaye          Reims    NA      51100   France
# 2     27 rue du Colonel Pierre Avia          Paris    NA      75508   France
# 3                78934 Hillside Dr.       Pasadena    CA      90003      USA
# 4                   7734 Strong St.  San Francisco    CA       None      USA
# ...                             ...            ...   ...        ...      ...
# 2818             C/ Moralzarzal, 86         Madrid    NA      28034    Spain
# 2819                    Torikatu 38           Oulu    NA      90110  Finland
# 2820             C/ Moralzarzal, 86         Madrid    NA      28034    Spain
# 2821          1 rue Alsace-Lorraine       Toulouse    NA      31000   France
# 2822             8616 Spinnaker Dr.         Boston    MA      51003      USA
#
#      TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 0                           Yu             Kwai    Small
# 1         EMEA         Henriot             Paul    Small
# 2         EMEA        Da Cunha           Daniel   Medium
# 3                        Young            Julie   Medium
# 4                        Brown            Julie   Medium
# ...        ...             ...              ...      ...
# 2818      EMEA          Freyre            Diego    Small
# 2819      EMEA       Koskitalo           Pirkko   Medium
# 2820      EMEA          Freyre            Diego   Medium
# 2821      EMEA          Roulet          Annette    Small
# 2822                   Yoshido             Juri   Medium
#
# [2823 rows x 24 columns]

# %%
# d. sorting status 

sorted_df = sales_df.sort_values(by='STATUS', ascending=True)
sorted_df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 638         10253               33     100.00                4  4459.62
# 2593        10167               46      70.11               10  3225.06
# 1899        10167               32      63.12                3  2019.84
# 117         10248               20     100.00                3  2910.40
# 2573        10262               33      90.75                6  2994.75
# ...           ...              ...        ...              ...      ...
# 1079        10282               36     100.00                3  4174.92
# 1080        10293               22     100.00                6  2418.24
# 1081        10306               40      91.76               11  3670.40
# 1063        10419               35     100.00                6  5926.90
# 0           10107               30      95.70                2  2871.00
#
#        ORDERDATE     STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...       PHONE  \
# 638   06/01/2004  Cancelled       2         6     2004  ...  1715552282
# 2593  10/23/2003  Cancelled       4        10     2003  ...  0695346555
# 1899  10/23/2003  Cancelled       4        10     2003  ...  0695346555
# 117   05/07/2004  Cancelled       2         5     2004  ...  2125557818
# 2573  06/24/2004  Cancelled       2         6     2004  ...   915559444
# ...          ...        ...     ...       ...      ...  ...         ...
# 1079  08/20/2004    Shipped       3         8     2004  ...  4155551450
# 1080  09/09/2004    Shipped       3         9     2004  ...  0114988555
# 1081  10/14/2004    Shipped       4        10     2004  ...  1715551555
# 1063  05/17/2005    Shipped       2         5     2005  ...    65629555
# 0     02/24/2003    Shipped       1         2     2003  ...  2125557818
#
#                       ADDRESSLINE1        CITY STATE POSTALCODE  COUNTRY  \
# 638   Berkeley Gardens 12  Brewery   Liverpool    NA    WX1 6LT       UK
# 2593                  ?kergatan 24       Boras    NA   S-844 67   Sweden
# 1899                  ?kergatan 24       Boras    NA   S-844 67   Sweden
# 117        897 Long Airport Avenue         NYC    NY      10022      USA
# 2573            C/ Moralzarzal, 86      Madrid    NA      28034    Spain
# ...                            ...         ...   ...        ...      ...
# 1079               5677 Strong St.  San Rafael    CA      97562      USA
# 1080           Via Monte Bianco 34      Torino    NA      10100    Italy
# 1081             Fauntleroy Circus  Manchester    NA    EC2 5NT       UK
# 1063                   Geislweg 14    Salzburg    NA       5020  Austria
# 0          897 Long Airport Avenue         NYC    NY      10022      USA
#
#      TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 638       EMEA           Devon        Elizabeth   Medium
# 2593      EMEA         Larsson            Maria   Medium
# 1899      EMEA         Larsson            Maria    Small
# 117                         Yu             Kwai    Small
# 2573      EMEA          Freyre            Diego    Small
# ...        ...             ...              ...      ...
# 1079                    Nelson          Valarie   Medium
# 1080      EMEA         Accorti            Paolo    Small
# 1081      EMEA        Ashworth         Victoria   Medium
# 1063      EMEA           Pipps            Georg   Medium
# 0                           Yu             Kwai    Small
#
# [2823 rows x 24 columns]

# %%
# e. Filtering the In Process status and order date to see which one to prioritize

filteredsales_df = sales_df[sales_df['STATUS'] == 'In Process']
sorted_filtered_df = filteredsales_df.sort_values(by='ORDERDATE', ascending=True)
sorted_filtered_df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER     SALES  \
# 855         10421               35     100.00                1   5433.75
# 1515        10420               37      60.37               13   2233.69
# 1437        10420               60      64.67               11   3880.20
# 1414        10420               36      57.73                7   2078.28
# 1715        10420               39     100.00                9   3933.93
# 1288        10420               66      92.95                6   6134.70
# 1791        10420               55      96.30                8   5296.50
# 1563        10420               45      26.88                1   1209.60
# 1867        10420               35      96.74               10   3385.90
# 752         10420               45     100.00                2   4977.00
# 1640        10421               40      45.70                2   1828.00
# 701         10420               36      63.57                4   2288.52
# 2045        10420               15      43.49                3    652.35
# 599         10420               37     100.00                5   5283.60
# 1943        10420               26     100.00               12   2617.16
# 2097        10423               28      78.89                4   2208.92
# 1139        10423               21      89.29                5   1875.09
# 500         10422               51      95.55                2   4873.05
# 987         10423               21      84.82                2   1781.22
# 934         10423               31      53.72                3   1665.32
# 907         10423               10      88.14                1    881.40
# 526         10422               25      51.75                1   1293.75
# 1743        10425               31      33.24                5   1030.44
# 2172        10425               41      86.68               11   3553.88
# 2249        10425               11      43.83                6    482.13
# 1667        10425               49     100.00                9   5510.54
# 2302        10424               44      61.41                2   2702.04
# 53          10424               50     100.00                6  12001.00
# 1341        10425               38     100.00               13   4325.16
# 1368        10424               26      59.87                4   1556.62
# 2405        10425               18     100.00                2   1895.94
# 1064        10425               28     100.00                8   3793.16
# 780         10425               19      49.22               10    935.18
# 727         10425               38      99.41                7   3777.58
# 679         10425               28     100.00                3   5318.04
# 447         10424               54     100.00                5   7182.00
# 393         10425               33     100.00                4   4692.60
# 239         10424               49     100.00                3   7969.36
# 160         10425               38     100.00               12   5894.94
# 1465        10425               55      46.82                1   2575.10
# 2640        10424               46      80.92                1   3722.32
#
#        ORDERDATE      STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...        PHONE  \
# 855   05/29/2005  In Process       2         5     2005  ...   4155551450
# 1515  05/29/2005  In Process       2         5     2005  ...  61294958555
# 1437  05/29/2005  In Process       2         5     2005  ...  61294958555
# 1414  05/29/2005  In Process       2         5     2005  ...  61294958555
# 1715  05/29/2005  In Process       2         5     2005  ...  61294958555
# 1288  05/29/2005  In Process       2         5     2005  ...  61294958555
# 1791  05/29/2005  In Process       2         5     2005  ...  61294958555
# 1563  05/29/2005  In Process       2         5     2005  ...  61294958555
# 1867  05/29/2005  In Process       2         5     2005  ...  61294958555
# 752   05/29/2005  In Process       2         5     2005  ...  61294958555
# 1640  05/29/2005  In Process       2         5     2005  ...   4155551450
# 701   05/29/2005  In Process       2         5     2005  ...  61294958555
# 2045  05/29/2005  In Process       2         5     2005  ...  61294958555
# 599   05/29/2005  In Process       2         5     2005  ...  61294958555
# 1943  05/29/2005  In Process       2         5     2005  ...  61294958555
# 2097  05/30/2005  In Process       2         5     2005  ...     02555467
# 1139  05/30/2005  In Process       2         5     2005  ...     02555467
# 500   05/30/2005  In Process       2         5     2005  ...   2155551555
# 987   05/30/2005  In Process       2         5     2005  ...     02555467
# 934   05/30/2005  In Process       2         5     2005  ...     02555467
# 907   05/30/2005  In Process       2         5     2005  ...     02555467
# 526   05/30/2005  In Process       2         5     2005  ...   2155551555
# 1743  05/31/2005  In Process       2         5     2005  ...     40678555
# 2172  05/31/2005  In Process       2         5     2005  ...     40678555
# 2249  05/31/2005  In Process       2         5     2005  ...     40678555
# 1667  05/31/2005  In Process       2         5     2005  ...     40678555
# 2302  05/31/2005  In Process       2         5     2005  ...    915559444
# 53    05/31/2005  In Process       2         5     2005  ...    915559444
# 1341  05/31/2005  In Process       2         5     2005  ...     40678555
# 1368  05/31/2005  In Process       2         5     2005  ...    915559444
# 2405  05/31/2005  In Process       2         5     2005  ...     40678555
# 1064  05/31/2005  In Process       2         5     2005  ...     40678555
# 780   05/31/2005  In Process       2         5     2005  ...     40678555
# 727   05/31/2005  In Process       2         5     2005  ...     40678555
# 679   05/31/2005  In Process       2         5     2005  ...     40678555
# 447   05/31/2005  In Process       2         5     2005  ...    915559444
# 393   05/31/2005  In Process       2         5     2005  ...     40678555
# 239   05/31/2005  In Process       2         5     2005  ...    915559444
# 160   05/31/2005  In Process       2         5     2005  ...     40678555
# 1465  05/31/2005  In Process       2         5     2005  ...     40678555
# 2640  05/31/2005  In Process       2         5     2005  ...    915559444
#
#                                  ADDRESSLINE1        CITY STATE POSTALCODE  \
# 855                           5677 Strong St.  San Rafael    CA      97562
# 1515  Monitor Money Building, 815 Pacific Hwy   Chatswood   NSW       2067
# 1437  Monitor Money Building, 815 Pacific Hwy   Chatswood   NSW       2067
# 1414  Monitor Money Building, 815 Pacific Hwy   Chatswood   NSW       2067
# 1715  Monitor Money Building, 815 Pacific Hwy   Chatswood   NSW       2067
# 1288  Monitor Money Building, 815 Pacific Hwy   Chatswood   NSW       2067
# 1791  Monitor Money Building, 815 Pacific Hwy   Chatswood   NSW       2067
# 1563  Monitor Money Building, 815 Pacific Hwy   Chatswood   NSW       2067
# 1867  Monitor Money Building, 815 Pacific Hwy   Chatswood   NSW       2067
# 752   Monitor Money Building, 815 Pacific Hwy   Chatswood   NSW       2067
# 1640                          5677 Strong St.  San Rafael    CA      97562
# 701   Monitor Money Building, 815 Pacific Hwy   Chatswood   NSW       2067
# 2045  Monitor Money Building, 815 Pacific Hwy   Chatswood   NSW       2067
# 599   Monitor Money Building, 815 Pacific Hwy   Chatswood   NSW       2067
# 1943  Monitor Money Building, 815 Pacific Hwy   Chatswood   NSW       2067
# 2097                      Rue Joseph-Bens 532   Bruxelles    NA     B-1180
# 1139                      Rue Joseph-Bens 532   Bruxelles    NA     B-1180
# 500                          7586 Pompton St.   Allentown    PA      70267
# 987                       Rue Joseph-Bens 532   Bruxelles    NA     B-1180
# 934                       Rue Joseph-Bens 532   Bruxelles    NA     B-1180
# 907                       Rue Joseph-Bens 532   Bruxelles    NA     B-1180
# 526                          7586 Pompton St.   Allentown    PA      70267
# 1743             67, rue des Cinquante Otages      Nantes    NA      44000
# 2172             67, rue des Cinquante Otages      Nantes    NA      44000
# 2249             67, rue des Cinquante Otages      Nantes    NA      44000
# 1667             67, rue des Cinquante Otages      Nantes    NA      44000
# 2302                       C/ Moralzarzal, 86      Madrid    NA      28034
# 53                         C/ Moralzarzal, 86      Madrid    NA      28034
# 1341             67, rue des Cinquante Otages      Nantes    NA      44000
# 1368                       C/ Moralzarzal, 86      Madrid    NA      28034
# 2405             67, rue des Cinquante Otages      Nantes    NA      44000
# 1064             67, rue des Cinquante Otages      Nantes    NA      44000
# 780              67, rue des Cinquante Otages      Nantes    NA      44000
# 727              67, rue des Cinquante Otages      Nantes    NA      44000
# 679              67, rue des Cinquante Otages      Nantes    NA      44000
# 447                        C/ Moralzarzal, 86      Madrid    NA      28034
# 393              67, rue des Cinquante Otages      Nantes    NA      44000
# 239                        C/ Moralzarzal, 86      Madrid    NA      28034
# 160              67, rue des Cinquante Otages      Nantes    NA      44000
# 1465             67, rue des Cinquante Otages      Nantes    NA      44000
# 2640                       C/ Moralzarzal, 86      Madrid    NA      28034
#
#         COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 855         USA                    Nelson          Valarie   Medium
# 1515  Australia      APAC          Huxley           Adrian    Small
# 1437  Australia      APAC          Huxley           Adrian   Medium
# 1414  Australia      APAC          Huxley           Adrian    Small
# 1715  Australia      APAC          Huxley           Adrian   Medium
# 1288  Australia      APAC          Huxley           Adrian   Medium
# 1791  Australia      APAC          Huxley           Adrian   Medium
# 1563  Australia      APAC          Huxley           Adrian    Small
# 1867  Australia      APAC          Huxley           Adrian   Medium
# 752   Australia      APAC          Huxley           Adrian   Medium
# 1640        USA                    Nelson          Valarie    Small
# 701   Australia      APAC          Huxley           Adrian    Small
# 2045  Australia      APAC          Huxley           Adrian    Small
# 599   Australia      APAC          Huxley           Adrian   Medium
# 1943  Australia      APAC          Huxley           Adrian    Small
# 2097    Belgium      EMEA           Dewey        Catherine    Small
# 1139    Belgium      EMEA           Dewey        Catherine    Small
# 500         USA                        Yu            Kyung   Medium
# 987     Belgium      EMEA           Dewey        Catherine    Small
# 934     Belgium      EMEA           Dewey        Catherine    Small
# 907     Belgium      EMEA           Dewey        Catherine    Small
# 526         USA                        Yu            Kyung    Small
# 1743     France      EMEA         Labrune           Janine    Small
# 2172     France      EMEA         Labrune           Janine   Medium
# 2249     France      EMEA         Labrune           Janine    Small
# 1667     France      EMEA         Labrune           Janine   Medium
# 2302      Spain      EMEA          Freyre            Diego    Small
# 53        Spain      EMEA          Freyre            Diego    Large
# 1341     France      EMEA         Labrune           Janine   Medium
# 1368      Spain      EMEA          Freyre            Diego    Small
# 2405     France      EMEA         Labrune           Janine    Small
# 1064     France      EMEA         Labrune           Janine   Medium
# 780      France      EMEA         Labrune           Janine    Small
# 727      France      EMEA         Labrune           Janine   Medium
# 679      France      EMEA         Labrune           Janine   Medium
# 447       Spain      EMEA          Freyre            Diego    Large
# 393      France      EMEA         Labrune           Janine   Medium
# 239       Spain      EMEA          Freyre            Diego    Large
# 160      France      EMEA         Labrune           Janine   Medium
# 1465     France      EMEA         Labrune           Janine    Small
# 2640      Spain      EMEA          Freyre            Diego   Medium
#
# [41 rows x 24 columns]

# %%
#f. Create a new column names Customer ID and put incremental details

sales_df['CUSTOMERID']=range(1,len(sales_df)+1)
sales_df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#        ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0     02/24/2003   Shipped       1         2     2003  ...
# 1     05/07/2003   Shipped       2         5     2003  ...
# 2     07/01/2003   Shipped       3         7     2003  ...
# 3     08/25/2003   Shipped       3         8     2003  ...
# 4     10/10/2003   Shipped       4        10     2003  ...
# ...          ...       ...     ...       ...      ...  ...
# 2818  12/02/2004   Shipped       4        12     2004  ...
# 2819  01/31/2005   Shipped       1         1     2005  ...
# 2820  03/01/2005  Resolved       1         3     2005  ...
# 2821  03/28/2005   Shipped       1         3     2005  ...
# 2822  05/06/2005   On Hold       2         5     2005  ...
#
#                        ADDRESSLINE1           CITY STATE POSTALCODE  COUNTRY  \
# 0           897 Long Airport Avenue            NYC    NY      10022      USA
# 1                59 rue de l'Abbaye          Reims    NA      51100   France
# 2     27 rue du Colonel Pierre Avia          Paris    NA      75508   France
# 3                78934 Hillside Dr.       Pasadena    CA      90003      USA
# 4                   7734 Strong St.  San Francisco    CA       None      USA
# ...                             ...            ...   ...        ...      ...
# 2818             C/ Moralzarzal, 86         Madrid    NA      28034    Spain
# 2819                    Torikatu 38           Oulu    NA      90110  Finland
# 2820             C/ Moralzarzal, 86         Madrid    NA      28034    Spain
# 2821          1 rue Alsace-Lorraine       Toulouse    NA      31000   France
# 2822             8616 Spinnaker Dr.         Boston    MA      51003      USA
#
#      TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE CUSTOMERID
# 0                           Yu             Kwai    Small          1
# 1         EMEA         Henriot             Paul    Small          2
# 2         EMEA        Da Cunha           Daniel   Medium          3
# 3                        Young            Julie   Medium          4
# 4                        Brown            Julie   Medium          5
# ...        ...             ...              ...      ...        ...
# 2818      EMEA          Freyre            Diego    Small       2819
# 2819      EMEA       Koskitalo           Pirkko   Medium       2820
# 2820      EMEA          Freyre            Diego   Medium       2821
# 2821      EMEA          Roulet          Annette    Small       2822
# 2822                   Yoshido             Juri   Medium       2823
#
# [2823 rows x 25 columns]

# %%
# g. Aggregated categorical column
aggregated_data = sales_df.groupby('PRODUCTLINE')['SALES'].sum().reset_index()
aggregated_data
# Out:
#         PRODUCTLINE       SALES
# 0      Classic Cars  3919615.66
# 1       Motorcycles  1166388.34
# 2            Planes   975003.57
# 3             Ships   714437.13
# 4            Trains   226243.47
# 5  Trucks and Buses  1127789.84
# 6      Vintage Cars  1903150.84

# %%
# Task B - Data Analysis

#a .
summary_stats = sales_df.groupby(['PRODUCTLINE', 'STATUS']).agg({
    'SALES': ['mean', 'sum', 'std'],
    'ORDERNUMBER': 'count'
}).reset_index()
summary_stats
# Out:
#          PRODUCTLINE      STATUS        SALES                           \
#                                          mean         sum          std
# 0       Classic Cars   Cancelled  3702.675625    59242.81  1608.945688
# 1       Classic Cars    Disputed  8670.956667    26012.87  1669.641725
# 2       Classic Cars  In Process  4125.761429    57760.66  2644.195007
# 3       Classic Cars     On Hold  4086.637500    49039.65  2061.881799
# 4       Classic Cars    Resolved  3224.917500    25799.34  1375.863172
# 5       Classic Cars     Shipped  4050.066007  3701760.33  2038.922560
# 6        Motorcycles    Disputed  5303.650000    31821.90  2709.079642
# 7        Motorcycles     On Hold  4992.610000     4992.61          NaN
# 8        Motorcycles     Shipped  3486.338981  1129573.83  1807.832891
# 9             Planes   Cancelled  2952.725833    35432.71  1679.434792
# 10            Planes    Disputed  1921.920000     3843.84   703.854090
# 11            Planes     On Hold  3858.614444    34727.53  2200.511530
# 12            Planes    Resolved  2877.743333    34532.92  1111.173212
# 13            Planes     Shipped  3197.293616   866466.57  1504.694860
# 14             Ships   Cancelled  3148.091667    56665.65  1217.907341
# 15             Ships    Disputed  3070.400000     3070.40          NaN
# 16             Ships     On Hold  2958.076250    23664.61   433.912826
# 17             Ships    Resolved  3321.975833    39863.71  1181.129751
# 18             Ships     Shipped  3031.655179   591172.76  1078.229796
# 19            Trains   Cancelled  5082.420000     5082.42          NaN
# 20            Trains     On Hold  5808.480000     5808.48          NaN
# 21            Trains     Shipped  2871.367600   215352.57  1414.576053
# 22  Trucks and Buses  In Process  3911.491818    43026.41  2383.080366
# 23  Trucks and Buses     On Hold  5048.322500    20193.29  2043.636003
# 24  Trucks and Buses    Resolved  4094.550000    20472.75  1681.418569
# 25  Trucks and Buses     Shipped  3715.649075  1044097.39  1636.431042
# 26      Vintage Cars   Cancelled  2927.991538    38063.89   912.883536
# 27      Vintage Cars    Disputed  3731.925000     7463.85  3503.466613
# 28      Vintage Cars  In Process  2746.430625    43942.89  1872.437010
# 29      Vintage Cars     On Hold  4505.891111    40553.02  4030.924180
# 30      Vintage Cars    Resolved  3004.956000    30049.56  2464.721520
# 31      Vintage Cars     Shipped  3129.403285  1743077.63  1725.862196
#
#    ORDERNUMBER
#          count
# 0           16
# 1            3
# 2           14
# 3           12
# 4            8
# 5          914
# 6            6
# 7            1
# 8          324
# 9           12
# 10           2
# 11           9
# 12          12
# 13         271
# 14          18
# 15           1
# 16           8
# 17          12
# 18         195
# 19           1
# 20           1
# 21          75
# 22          11
# 23           4
# 24           5
# 25         281
# 26          13
# 27           2
# 28          16
# 29           9
# 30          10
# 31         557

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
#  16  CITY              2823 non-null   object
#  17  STATE             2823 non-null   object
#  18  POSTALCODE        2823 non-null   object
#  19  COUNTRY           2823 non-null   object
#  20  TERRITORY         2823 non-null   object
#  21  CONTACTLASTNAME   2823 non-null   object
#  22  CONTACTFIRSTNAME  2823 non-null   object
#  23  DEALSIZE          2823 non-null   object
#  24  CUSTOMERID        2823 non-null   int64
# dtypes: float64(2), int64(8), object(15)
# memory usage: 551.5+ KB

# %%
# b. 
numeric_columns = ['QUANTITYORDERED', 'PRICEEACH', 'SALES',
                    'MSRP']

correlation_matrix = sales_df[numeric_columns].corr()
correlation_matrix
# Out:
#                  QUANTITYORDERED  PRICEEACH     SALES      MSRP
# QUANTITYORDERED         1.000000   0.005564  0.551426  0.017881
# PRICEEACH               0.005564   1.000000  0.657841  0.670625
# SALES                   0.551426   0.657841  1.000000  0.635239
# MSRP                    0.017881   0.670625  0.635239  1.000000

# %%
# c. 

sales_df.to_csv('Sales.csv', index=False)
print('Successfully saved file: Sales.csv')
# Out:
# Successfully saved file: Sales.csv

# %%
# d. 

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 
plt.figure(figsize=(8, 6))
sns.boxplot(x=sales_df['SALES'])
plt.title('Boxplot of SALES')
plt.xlabel('SALES')
plt.show()

# %%
sales_df.shape
# Out:
# (2823, 25)

# %%
# Perform removal of outliers using ZScore

from scipy.stats import zscore
 
# Calculate Z-scores for the 'SALES' column
sales_df['Z_SCORES'] = zscore(sales_df['SALES'])

# Set a threshold for Z-scores to identify outliers
z_score_threshold = 1

# Filter the DataFrame to exclude outliers
sales_df = sales_df[abs(sales_df['Z_SCORES']) <= z_score_threshold]

# Drop the temporary column 'Z_SCORES'
sales_df = sales_df.drop(columns=['Z_SCORES'])
sales_df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2817        10337               42      97.16                5  4080.72
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#        ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0     02/24/2003  Shipped       1         2     2003  ...
# 1     05/07/2003  Shipped       2         5     2003  ...
# 2     07/01/2003  Shipped       3         7     2003  ...
# 3     08/25/2003  Shipped       3         8     2003  ...
# 4     10/10/2003  Shipped       4        10     2003  ...
# ...          ...      ...     ...       ...      ...  ...
# 2817  11/21/2004  Shipped       4        11     2004  ...
# 2818  12/02/2004  Shipped       4        12     2004  ...
# 2819  01/31/2005  Shipped       1         1     2005  ...
# 2821  03/28/2005  Shipped       1         3     2005  ...
# 2822  05/06/2005  On Hold       2         5     2005  ...
#
#                        ADDRESSLINE1           CITY STATE POSTALCODE  COUNTRY  \
# 0           897 Long Airport Avenue            NYC    NY      10022      USA
# 1                59 rue de l'Abbaye          Reims    NA      51100   France
# 2     27 rue du Colonel Pierre Avia          Paris    NA      75508   France
# 3                78934 Hillside Dr.       Pasadena    CA      90003      USA
# 4                   7734 Strong St.  San Francisco    CA       None      USA
# ...                             ...            ...   ...        ...      ...
# 2817               5905 Pompton St.            NYC    NY      10022      USA
# 2818             C/ Moralzarzal, 86         Madrid    NA      28034    Spain
# 2819                    Torikatu 38           Oulu    NA      90110  Finland
# 2821          1 rue Alsace-Lorraine       Toulouse    NA      31000   France
# 2822             8616 Spinnaker Dr.         Boston    MA      51003      USA
#
#      TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE CUSTOMERID
# 0                           Yu             Kwai    Small          1
# 1         EMEA         Henriot             Paul    Small          2
# 2         EMEA        Da Cunha           Daniel   Medium          3
# 3                        Young            Julie   Medium          4
# 4                        Brown            Julie   Medium          5
# ...        ...             ...              ...      ...        ...
# 2817                 Hernandez            Maria   Medium       2818
# 2818      EMEA          Freyre            Diego    Small       2819
# 2819      EMEA       Koskitalo           Pirkko   Medium       2820
# 2821      EMEA          Roulet          Annette    Small       2822
# 2822                   Yoshido             Juri   Medium       2823
#
# [2005 rows x 25 columns]

# %%
sales_df.shape
# Out:
# (2005, 25)

# %%
# Boxplot without outliers
plt.figure(figsize=(8, 6))
sns.boxplot(x=sales_df['SALES'])
plt.title('Boxplot of SALES')
plt.xlabel('SALES')
plt.show()

# %%
numeric_columns = ['QUANTITYORDERED', 'PRICEEACH', 'SALES',
                    'MSRP']

correlation_matrix = sales_df[numeric_columns].corr()
correlation_matrix

# Visualize the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %%
# Visualize a scatter plot of SALES and PRICEEACH
plt.figure(figsize=(8, 6))
sns.scatterplot(data=sales_df, x='SALES', y='PRICEEACH')
plt.title('Scatter Plot: SALES vs PRICEEACH')
plt.show()

# %%
sales_df.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count   2005.000000      2005.000000  2005.000000      2005.000000
# mean   10257.016958        34.563591    86.189845         6.642394
# std       91.365674         8.861406    16.590177         4.298528
# min    10100.000000        12.000000    29.540000         1.000000
# 25%    10178.000000        27.000000    73.980000         3.000000
# 50%    10262.000000        34.000000    94.580000         6.000000
# 75%    10331.000000        42.000000   100.000000        10.000000
# max    10425.000000        66.000000   100.000000        18.000000
#
#              SALES       QTR_ID     MONTH_ID      YEAR_ID         MSRP  \
# count  2005.000000  2005.000000  2005.000000  2005.000000  2005.000000
# mean   3252.263840     2.724190     7.104738  2003.803990    98.756608
# std     973.191566     1.212558     3.685084     0.690674    33.814668
# min    1713.690000     1.000000     1.000000  2003.000000    33.000000
# 25%    2443.290000     2.000000     4.000000  2003.000000    72.000000
# 50%    3157.440000     3.000000     8.000000  2004.000000    97.000000
# 75%    3958.460000     4.000000    11.000000  2004.000000   118.000000
# max    5393.640000     4.000000    12.000000  2005.000000   214.000000
#
#         CUSTOMERID
# count  2005.000000
# mean   1486.168579
# std     820.713912
# min       1.000000
# 25%     790.000000
# 50%    1487.000000
# 75%    2221.000000
# max    2823.000000

# %%
sales_df = sales_df.replace([np.inf, -np.inf], np.nan)

# Visualize a histogram of SALES
plt.figure(figsize=(15, 6))
sns.histplot(data=sales_df, x='PRODUCTLINE', element='bars', stat='density', common_norm=False, kde=False)
plt.title('Histogram of PRODUCTLINE')
plt.show()
# Out:
# C:\Users\torri\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#Point plot 

import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
sns.pointplot(x='PRODUCTLINE', y='SALES', data=sales_df, capsize=0.2)
plt.title('Point Plot: Average Sales by Product Line')
plt.xlabel('Product Line')
plt.ylabel('Average Sales')
plt.show()

# %%
#Bar Plot

import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
sns.barplot(x='PRODUCTLINE', y='SALES', data=sales_df)
plt.title('Bar Plot: Average Sales by Product Line')
plt.xlabel('Product Line')
plt.ylabel('Average Sales')
plt.show()

# %%
#e.
# Analysis of Variance (ANOVA)
# Testing if there are any statistically significant differences among Product Lines.

from scipy.stats import f_oneway

grouped_data = [sales_df[sales_df['PRODUCTLINE'] == productline]['SALES'] for productline in sales_df['PRODUCTLINE'].unique()]

# Perform ANOVA
f_statistic, p_value = f_oneway(*grouped_data)

# Print the results
print(f"F-statistic: {f_statistic}")
print(f"P-value: {p_value}")

# Interpret the results
if p_value < 0.05:
    print("There are significant differences among PRODUCTLINE means.")
else:
    print("There are no significant differences among PRODUCTLINE means.")
# Out:
# F-statistic: 11.998883325816832
# P-value: 2.8058279230390855e-13
# There are significant differences among PRODUCTLINE means.

# %%
sales_df['DEALSIZE'].unique()
# Out:
# array(['Small', 'Medium'], dtype=object)

# %%
# Task C - Data Findings and Decision Support

#a. 
 
grouped_data = sales_df.groupby(['PRODUCTLINE']).agg({
    'SALES': ['sum'],
    'ORDERNUMBER': 'count',
    'QUANTITYORDERED': 'mean',
    'PRICEEACH': 'mean'
}).reset_index()

grouped_data = grouped_data.sort_values(by=('SALES', 'sum'), ascending=False)
grouped_data
# Out:
#         PRODUCTLINE       SALES ORDERNUMBER QUANTITYORDERED  PRICEEACH
#                             sum       count            mean       mean
# 0      Classic Cars  2153742.49         621       33.315620  89.450258
# 6      Vintage Cars  1340566.89         426       35.488263  83.643333
# 1       Motorcycles   786032.93         243       34.744856  85.616749
# 2            Planes   717980.36         234       35.692308  83.272906
# 5  Trucks and Buses   716239.68         211       34.364929  89.427725
# 3             Ships   633635.73         210       34.776190  84.934095
# 4            Trains   172590.92          60       35.733333  77.230500

# %%
grouped_data = sales_df.sort_values(by='SALES', ascending=False)
grouped_data = grouped_data.groupby(['CITY', 'PRODUCTLINE']).agg({'SALES': ['sum']})
grouped_data = grouped_data.sort_values(by=('SALES','sum'), ascending=False)
grouped_data
# Out:
#                                 SALES
#                                   sum
# CITY          PRODUCTLINE
# Madrid        Classic Cars  276342.33
# NYC           Classic Cars  144397.00
# Madrid        Vintage Cars  134527.97
# San Rafael    Classic Cars  134141.69
#               Vintage Cars  107388.69
# ...                               ...
# Reggio Emilia Vintage Cars    1921.41
# Munich        Vintage Cars    1863.40
# Bruxelles     Trains          1855.41
# White Plains  Trains          1804.44
# Aaarhus       Ships           1753.06
#
# [323 rows x 1 columns]

# %%
grouped_country_data = sales_df.groupby(['COUNTRY']).agg({
    'SALES': ['sum'],
    'ORDERNUMBER': 'count', 
}).reset_index()

grouped_country_data = grouped_country_data.sort_values(by=('SALES', 'sum'), ascending=False)
grouped_country_data
# Out:
#         COUNTRY       SALES ORDERNUMBER
#                         sum       count
# 18          USA  2363474.28         721
# 14        Spain   793625.96         241
# 6        France   710609.24         222
# 0     Australia   435914.58         131
# 17           UK   355834.91         110
# 9         Italy   270273.12          82
# 5       Finland   212502.37          65
# 11       Norway   178885.56          55
# 3        Canada   178231.78          59
# 13    Singapore   172338.02          53
# 1       Austria   130121.66          39
# 7       Germany   128958.19          41
# 15       Sweden   125193.06          39
# 4       Denmark   117850.27          39
# 10        Japan    96442.59          33
# 16  Switzerland    86661.96          23
# 2       Belgium    63621.70          21
# 12  Philippines    62113.33          20
# 8       Ireland    38136.42          11

# %%
grouped_territory_data = sales_df.groupby(['TERRITORY']).agg({
    'SALES': ['sum'],
    'ORDERNUMBER': 'count', 
}).reset_index()

grouped_territory_data = grouped_territory_data.sort_values(by=('SALES', 'sum'), ascending=False)
grouped_territory_data
# Out:
#   TERRITORY       SALES ORDERNUMBER
#                     sum       count
# 2      EMEA  3212274.42         988
# 0            2541706.06         780
# 1      APAC   511000.03         155
# 3     Japan   255808.49          82

# %%
grouped_territory_data = sales_df.groupby(['QTR_ID']).agg({
    'SALES': ['sum'],
    'ORDERNUMBER': 'count', 
}).reset_index()

grouped_territory_data = grouped_territory_data.sort_values(by=('SALES', 'sum'), ascending=False)
grouped_territory_data
# Out:
#   QTR_ID       SALES ORDERNUMBER
#                  sum       count
# 3      4  2573959.99         789
# 0      1  1586772.30         484
# 1      2  1185377.26         374
# 2      3  1174679.45         358

# %%
grouped_territory_data = sales_df.groupby(['DEALSIZE']).agg({
    'SALES': ['sum'],
    'ORDERNUMBER': 'count', 
}).reset_index()

grouped_territory_data = grouped_territory_data.sort_values(by=('SALES', 'sum'), ascending=False)
grouped_territory_data
# Out:
#   DEALSIZE       SALES ORDERNUMBER
#                    sum       count
# 0   Medium  4390470.64        1104
# 1    Small  2130318.36         901

# %%
print(f'Average quantity ordered is : {sales_df["QUANTITYORDERED"].mean()}')
print(f'Average price each is : {sales_df["PRICEEACH"].mean()}')
print(f'Lowest Sales is : {sales_df["SALES"].min()}')
# Out:
# Average quantity ordered is : 34.56359102244389
# Average price each is : 86.18984538653368
# Lowest Sales is : 1713.69

# %%
sales_df['PRODUCTLINE'].unique()
# Out:
# array(['Motorcycles', 'Classic Cars', 'Trucks and Buses', 'Vintage Cars',
#        'Planes', 'Ships', 'Trains'], dtype=object)

# %%
related_columns = ['QUANTITYORDERED', 'PRICEEACH',
                    'MSRP', 'SALES']

correlation_matrix = sales_df[related_columns].corr()
correlation_matrix
# Out:
#                  QUANTITYORDERED  PRICEEACH      MSRP     SALES
# QUANTITYORDERED         1.000000  -0.423357 -0.337305  0.335612
# PRICEEACH              -0.423357   1.000000  0.623352  0.604682
# MSRP                   -0.337305   0.623352  1.000000  0.471174
# SALES                   0.335612   0.604682  0.471174  1.000000

# %%
from scipy.stats import f_oneway

# Assuming 'df' is your DataFrame
small_deals = sales_df[sales_df['DEALSIZE'] == 'Small']['SALES']
medium_deals = sales_df[sales_df['DEALSIZE'] == 'Medium']['SALES']
large_deals = sales_df[sales_df['DEALSIZE'] == 'Large']['SALES']

# Performing one-way ANOVA test
f_statistic, p_value = f_oneway(small_deals, medium_deals, large_deals)

# Displaying the results
print(f'F-statistic: {f_statistic}')
print(f'P-value: {p_value}')

# Checking significance level (e.g., 0.05)
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis. There is a significant difference in average sales.")
else:
    print("Fail to reject the null hypothesis. There is no significant difference in average sales.")
# Out:
# F-statistic: nan
# P-value: nan
# Fail to reject the null hypothesis. There is no significant difference in average sales.
# C:\Users\torri\anaconda3\Lib\site-packages\scipy\stats\_stats_py.py:4133: DegenerateDataWarning: at least one input has length 0
#   warnings.warn(stats.DegenerateDataWarning('at least one input '
